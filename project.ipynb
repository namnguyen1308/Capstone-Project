# %% [markdown]
# <a href="https://colab.research.google.com/github/namnguyen1308/Capstone-Project/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="pBjL8yCvvqdqKvcPLsdS")
project = rf.workspace("ppe-wllkh").project("construction-ppe-rdhzo-t7zjz")
version = project.version(2)
dataset = version.download("yolov12")

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO12n model
model = YOLO("yolo12n.pt")

# Train the model on the data example dataset for 100 epochs
results = model.train(data="/content/Construction-PPE-2/data.yaml", epochs=100, imgsz=640)

# %%
# !yolo train model=last.pt data=/content/dataset/data.yaml epochs=100 imgsz=640 resume=True
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp /content/drive/MyDrive/Colab\ Notebooks/runs/detect/train/weights/last.pt ./last.pt
# !yolo train model=last.pt data=/content/dataset/data.yaml epochs=100 imgsz=640 resume=True
